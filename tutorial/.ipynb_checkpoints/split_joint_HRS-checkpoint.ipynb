# %%
import collections
import glob 
import os
import warnings
from glob import glob
                                                                 
import joblib                                                    
import matplotlib.pyplot as plt                                  
import numpy as np                                               
from astropy import table                                        
from astropy.io import fits
import laspec
from laspec import normalization as lanorm
import lightkurve as lk

import copy
import os
import datetime
import logging
import warnings

import numpy as np
from scipy import signal
from scipy.interpolate import interp1d
from scipy.stats import binned_statistic
from matplotlib import pyplot as plt
from copy import deepcopy
from tqdm import tqdm
import pandas as pd

from astropy.stats import sigma_clip
from astropy.table import Table
from astropy.io import fits
from astropy.time import Time
from astropy import units as u
import lightkurve as lk

import warnings
warnings.filterwarnings('ignore')

# %%
### https://python4astronomers.github.io/astropy-UVES/UVES.html#normalize-the-flux-to-the-local-continuum

# %%
dire = '/media/backup/216BFOSC/20201216_bfosc/'
fwave = 'fear-20201216-0025.fit.dump'
fflux = 'star-20201216-0027.fit.dump'
fflat = 'flat-20201216-0017.fit.dump'


wave1 = joblib.load(os.path.join(dire, fwave))['wave_solu']
flux1 = joblib.load(os.path.join(dire, fflux))
flat1 = joblib.load(os.path.join(dire, fflat))
fig = plt.figure(figsize=(13,8))
ax = fig.add_subplot(211)
for i in np.arange(wave1.shape[0]):
    ax.plot(wave1[i], flux1['spec_extr'][i])
plt.ylim(0,2500)

ax = fig.add_subplot(212)
ax.set_title('divide flat')
for i in np.arange(wave1.shape[0])[3:4]:
    ax.plot(wave1[i], flux1['spec_sum'][i]/flat1['spec_sum'][i])
plt.ylim(0,2)
# Out:
# (0.0, 2.0)

# %%
np.min(np.diff(wave1, axis=1))
# Out:
# 0.24488666012348403

# %%
### TYC3340-2437-1 04:11:10.00   +50:42:29.0 
def get_filelist(dire, fwave, fflux, nulist):
    '''get file name list
    parameters:
    ------------
    dire [str] e.g. '/media/backup/216BFOSC/20201218_bfosc/'
    fwave [str] name of wave file, e.g. 'fear-20201218-{:04d}.fit.dump'
    fflux [str] name of flux file, e.g. 'star-20201218-{:04d}.fit.dump'
    nulist [list] e.g. [[27, 26], [36, 35], [49, 50]]
    return:
    ----------------
    filelist [list] full name list for all spectra
             filelist[i][0] wave
             filelist[i][1] flux
    '''
    flist = [[os.path.join(dire, fwave.format(_[0])), os.path.join(dire, fflux.format(_[1]))] for _ in nulist]
    return flist
    
dirname = '/media/backup/216BFOSC/sdOB_216bfosc/216_sdOB/backup_216_sdOB'
###-----------20201216----------------------------
dire1 = f'{dirname}/20201216_bfosc/'
fwave1 = 'fear-20201216-{:04d}.fit.dump'
fflux1 = 'star-20201216-{:04d}.fit.dump'
list16 = [[30, 31], [41, 40], [54, 55]]
f1216 = [[os.path.join(dire1, fwave1.format(_[0])), os.path.join(dire1, fflux1.format(_[1]))] for _ in list16]
###-----------20201217----------------------------
dire2 = f'{dirname}/20201217_bfosc/'
fwave2 = 'fear-20201217-{:04d}.fit.dump'
fflux2 = 'star-20201217-{:04d}.fit.dump'
list17 = [[27, 26], [36, 35], [49, 50]]
f1217 = [[os.path.join(dire2, fwave2.format(_[0])), os.path.join(dire2, fflux2.format(_[1]))] for _ in list17]

###-----------20201218----------------------------
dire3 = f'{dirname}/20201218_bfosc/'
fwave3 = 'fear-20201218-{:04d}.fit.dump'
fflux3 = 'star-20201218-{:04d}.fit.dump'
list18 = [[16, 17], [32, 31], [56, 55]]
f1218 = [[os.path.join(dire3, fwave3.format(_[0])), os.path.join(dire3, fflux3.format(_[1]))] for _ in list18]

###-----------20201219----------------------------
dire19 = f'{dirname}/20201219_bfosc/'
fwave19 = 'fear-20201219-{:04d}.fit.dump'
fflux19 = 'star-20201219-{:04d}.fit.dump'
list19 = [[29, 30], [42, 43], [63, 64]]
f1219 = get_filelist(dire19, fwave19, fflux19, list19)

###-----------20201219----------------------------
dire19 = f'{dirname}/20201219_bfosc/'
fwave19 = 'fear-20201219-{:04d}.fit.dump'
fflux19 = 'star-20201219-{:04d}.fit.dump'
list19 = [[29, 30], [42, 43], [63, 64]]
f1219 = get_filelist(dire19, fwave19, fflux19, list19)

###-----------20201219----------------------------
dire19 = f'{dirname}/20201219_bfosc/'
fwave19 = 'fear-20201219-{:04d}.fit.dump'
fflux19 = 'star-20201219-{:04d}.fit.dump'
list19 = [[29, 30], [42, 43], [63, 64]]
f1219 = get_filelist(dire19, fwave19, fflux19, list19)

# %%
def combine_wave_flux(fwave, fflux):
    '''combine the wavelength and fflux to a dic
    parameters:
    ------------------
    fwave [str] file name of wavelength e.g. /media/backup/216BFOSC/20201218_bfosc/fear-20201218-0056.fit.dump
    fflux [str] file name of flux, e.g. '/media/backup/216BFOSC/20201218_bfosc/star-20201218-0055.fit.dump'
    '''
    star = {}
    star['wavelength'] = joblib.load(fwave)
    star['flux'] = joblib.load(fflux)
    return star

# %%
def rmcosimic(spec, sigma =8, itera=2, percentile=100,window_length=7, 
              polyorder=2, 
              show=False):
    '''remove cosimic line of spec
    parameters:
    --------------
    spec [class of lk.LightCurve] e.g. lk.LightCurve(time=wv,  flux=flx, flux_err=flx_err)
    sigma [float] exclude the flux which sigma*std
    itera [int] iteration number to calculate std
    percntile [float]
    window_length [odd]
    '''
    
    lc = spec.copy()
    ind_good = np.ones(len(lc.flux), dtype=np.bool)
    lc_detrend, lc_trend = lc.flatten(window_length=window_length, polyorder=polyorder, return_trend=True,
                break_tolerance=5, niters=3, sigma=3, mask=None)
    lcflux = spec.flux[ind_good] 
    lctrendflux = lc_trend.flux[ind_good]
    for i in np.arange(itera):
        diff_flux = lcflux  - lctrendflux
        std = np.std(diff_flux[diff_flux < np.percentile(diff_flux, percentile)])
        ind_good = diff_flux < sigma*std
        lcflux = lcflux[ind_good]
        lctrendflux= lctrendflux[ind_good]
        
    ind_bad = (lc.flux - lc_trend.flux) > sigma*std
    lc.flux[ind_bad] = np.interp(lc.time[ind_bad], lc.time[~ind_bad], lc.flux[~ind_bad])
    lc.flux_err[ind_bad] = np.sqrt(np.interp(lc.time[ind_bad], lc.time[~ind_bad], (lc.flux_err[~ind_bad])**2))
    if show:
       spec.scatter(color='b', )
       plt.plot(lc.time, lc.flux)
    return lc


#spec = lk.LightCurve(time=wv,  flux=flx, flux_err=flx_err)
#spec0 = rmcosimic(spec, sigma =7, itera=2, percentile=99,window_length=7, 
#              polyorder=2, 
#              show=True)

# %% [markdown]
# ### check remove the comsimic line

# %%
speclist = f1216+f1217+f1218+f1219
flist = speclist[1]
star = combine_wave_flux(flist[0], flist[1])
wave = star['wavelength']['wave_solu']
flux = star['flux']['spec_extr']
flux_err = star['flux']['err_sum']
#fig = plt.figure(figsize=(13,4))
#ax = fig.add_subplot(111)
for i in np.arange(wave.shape[0])[0:1]:
    spec = lk.LightCurve(time=wave[i],  flux=flux[i], flux_err=flux_err[i])
    spec0 = rmcosimic(spec, sigma =6, itera=2, percentile=100,window_length=7, 
              polyorder=2, 
              show=True)
#plt.ylim(0,9000)

# %% [markdown]
# ### creat a grid for caculating radial velocity

# %%
def read_tlusty(fname):
    hdulist = fits.open(fname)
    flux= hdulist[0].data
    hd = hdulist[0].header
    wave = hd['CRVAL1'] +np.arange(hd['NAXIS1'])*hd['CDELT1']
    hdulist.close()
    return wave, flux

# %% [markdown]
# ### Creat a RVM mod

# %%
import os
from laspec import convolution

### creat RVM mod with ispec grid of tlusty
dire = "/home/lcq/programs/iSpec_v20190302/input/grid/TLUSTY_OSTAR2006.300_750_nm/grid"
Teff_grid = [27500, 30000, 32500, 37500, 40000]
logg_grid = [3.5, 4.0, 4.5]
pmod = np.zeros((len(Teff_grid)*len(logg_grid), 4))
hdulist = fits.open('30000_3.50_0.00_0.00_10.00_0.00_0.00_0.00.fits.gz')
flx_ispec = hdulist[0].data
hd_ispec = hdulist[0].header
wave_mod = (hd_ispec['CRVAL1'] +np.arange(hd_ispec['NAXIS1'])*hd_ispec['CDELT1'])*10
hdulist.close()
flux_mod = np.zeros((len(Teff_grid)*len(logg_grid), len(wave_mod)))
modi = 0
for Teff in Teff_grid:
    for logg in logg_grid:
        pmod[modi] = np.array([Teff, logg, 0, 0])
        fname = '{0}_{1:.2f}_0.00_0.00_10.00_0.00_0.00_0.00.fits.gz'.format(27500, 3.5)
        fullfname = os.path.join(dire, fname)
        #wv_new, flux_mod[modi] = convolution.conv_spec(wave_mod, fits.getdata(fullfname), R_hi=300000., R_lo=2500., over_sample_additional=1,
        #      gaussian_kernel_sigma_num=5., wave_new=wave_mod,
        #      wave_new_oversample=1, verbose=False, return_type='array')
        flux_mod[modi] = fits.getdata(fullfname)
        modi +=1

# %%
basename = os.path.basename(fname)
basename
# Out:
# '27500_3.50_0.00_0.00_10.00_0.00_0.00_0.00.fits.gz'

# %%
### creat RVM mod with ispec grid of tlusty

def create_rvmod(fname):
    wavemod, flux = read_tlusty(fname)
    flux_modi, flux_smoothed2 =lanorm.normalize_spectrum_spline(wavemod, flux, p=1E-6, q=0.6, lu=(-1, 3), binwidth=30,
                                      niter=5)
    basename = os.path.basename(fname)
    if basename[0] is 'C' : Z = 2.
    if basename[0] is 'G' : Z = 1.
    if basename[0] is 'L' : Z = 1/2.
    if basename[0] is 'S' : Z = 1/5.
    if basename[0] is 'T' : Z = 1/10.
    if basename[0] is 'V' : Z = 1/30.
    if basename[0] is 'W' : Z = 1/50.
    if basename[0] is 'X' : Z = 1/100.
    if basename[0] is 'Y' : Z = 1/1000.
    if basename[0] is 'Z' : Z = 0
    Teff = np.float(basename[1:6])
    logg = np.float(basename[7:10])/100
    vsini = np.float(basename[11:13]) 
    pmodi = np.array([Teff, logg, vsini,  Z])
    return pmodi, flux_modi

#dirname = "/media/share/lijiao/TLUSTY_grid/TLUSTY_OSTAR2002_R2500/"
#modlist = glob(os.path.join(dirname, '*.fits.gz'))
#rvmod = joblib.Parallel(n_jobs=15, )(joblib.delayed(create_rvmod)(fname) for fname in modlist)

# %%
#joblib.dump(rvmod, '../dump/rvmod_R2500.dump')
rvmod = joblib.load('../dump/rvmod_R2500.dump')

# %%
### creat RVM mod with ispec grid of tlusty
dirname = "/media/share/lijiao/TLUSTY_grid/TLUSTY_OSTAR2002_R2500/"
modlist = glob(os.path.join(dirname, '*.fits.gz'))

pmod = np.zeros((len(modlist), 4))
wave_mod, flux = read_tlusty(modlist[0])
flux_mod = np.zeros((len(modlist), len(wave_mod)))


modi = 0
#for fname in modlist:
#    flux = fits.getdata(fname)
#    flux_mod[modi], flux_smoothed2 =lanorm.normalize_spectrum_spline(wavemod, flux, p=1E-6, q=0.6, lu=(-1, 3), binwidth=30,
#                                      niter=5)
#    
#    basename = os.path.basename(fname)
#    if basename[0] is 'C' : Z = 2.
#    if basename[0] is 'G' : Z = 1.
#    if basename[0] is 'L' : Z = 1/2.
#    if basename[0] is 'S' : Z = 1/5.
#    if basename[0] is 'T' : Z = 1/10.
#    if basename[0] is 'V' : Z = 1/30.
#    if basename[0] is 'W' : Z = 1/50.
#    if basename[0] is 'X' : Z = 1/100.
#    if basename[0] is 'Y' : Z = 1/1000.
#    if basename[0] is 'Z' : Z = 0
#    Teff = np.float(basename[1:6])
#    logg = np.float(basename[7:10])/100
#    vsini = np.float(basename[11:13]) 
#    pmod[modi] = np.array([Teff, logg, vsini,  Z])
#    modi +=1


NTeff_LT_35000 = 0
for rvmodi in rvmod:
    if (rvmodi[0][0] == 32500) & (rvmodi[0][1] == 4.0): NTeff_LT_35000 +=1
        
pmod = np.zeros((NTeff_LT_35000, 4))
flux_mod = np.zeros((NTeff_LT_35000, len(wave_mod)))
modi = 0
for rvmodi in rvmod:
    if (rvmodi[0][0] == 32500) & (rvmodi[0][1] == 4.0) :
       pmod[modi] = rvmodi[0]
       flux_mod[modi] = rvmodi[1]
       modi += 1

# %%
pmod
# Out:
# array([[3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 2.00000000e-01],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 5.00000000e-01],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 3.33333333e-02],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 2.00000000e-02],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 1.00000000e-03],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 1.00000000e+00],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 1.00000000e-02],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 1.00000000e-01],
#        [3.25000000e+04, 4.00000000e+00, 1.00000000e+01, 2.00000000e+00]])

# %% [markdown]
# ### Guo, Yanjun estimate value
# - Teff = 32719
# - logg = 4.12
# - Z = -0.528
# - $v\sin i$ = 138

# %%
from laspec.ccf import RVM
rvm = RVM(pmod, wave_mod, flux_mod, npix_lv=5)
# Out:
# @RVM: initializing Radial Velocity Machine (RVM)...
# @RVM: calculating local variance ...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   9 | elapsed:   12.3s remaining:   43.2s
# [Parallel(n_jobs=-1)]: Done   3 out of   9 | elapsed:   12.5s remaining:   25.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:   12.7s remaining:   15.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   9 | elapsed:   13.1s remaining:   10.4s
# [Parallel(n_jobs=-1)]: Done   6 out of   9 | elapsed:   13.5s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done   7 out of   9 | elapsed:   14.5s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:   16.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:   16.3s finished

# %%
hdulist = fits.open('30000_3.50_0.00_0.00_10.00_0.00_0.00_0.00.fits.gz')
flx_ispec = hdulist[0].data
hd_ispec = hdulist[0].header
wv_ispec = (hd_ispec['CRVAL1'] +np.arange(hd_ispec['NAXIS1'])*hd_ispec['CDELT1'])*10
hdulist.close()
from laspec import convolution
wv_new, flux_new = convolution.conv_spec(wv_ispec, flx_ispec, R_hi=300000., R_lo=2500., over_sample_additional=1,
              gaussian_kernel_sigma_num=5., wave_new=wv_ispec,
              wave_new_oversample=1, verbose=True, return_type='array')
# Out:
# ...
# @laspec.convolution.conv_spec: starting at 2021-03-09 17:33:16.474172
# @laspec.convolution.conv_spec: interpolating orignal spectrum to wave_interp ...
# @laspec.convolution.conv_spec: generating gaussian kernel array ...
# @laspec.convolution.conv_spec: convolving ...
# @laspec.convolution.conv_spec: using user-specified wave array ...
# @laspec.convolution.conv_spec: interpolating convolved spectrum to new wave array ...
# @laspec.convolution.conv_spec: total time spent: 4.00 seconds
# ...

# %% [markdown]
# ### check the broaded specta

# %%
import pandas as pd
wvtt, fluxtt = read_tlusty('/media/share/lijiao/TLUSTY_grid/TLUSTY_OSTAR2002_R2500/L40000g400v10.fits.gz')
fname = '/home/lcq/Documents/tlusty/ipynb/tmp/L40000g400v10.vis.7.gz'
data = pd.read_table(fname, delim_whitespace=True,names=['wavelength', 'flux'])
plt.plot(wvtt, fluxtt)
plt.plot(data.wavelength, data.flux)
plt.xlim(6500, 6600)
plt.ylim(0, 5e7)
# Out:
# (0.0, 50000000.0)

# %%
#from laspec import ccf
#from scipy.optimize import minimize 
#
#def wxcorr_spec_cost(rv, wave_obs, flux_obs, wave_mod, flux_mod, w_mod=None, w_obs=None):
#    """ the negative of wxcorr_spec, used as cost function for minimiztion """
#    return - wxcorr_spec(rv, wave_obs, flux_obs, wave_mod, flux_mod, w_mod, w_obs)
#
#wave_obs, flux_obs = spec0.time[ind_good], flux_norm[ind_good]
#rv_grid, ccf_grid = ccf.wxcorr_rvgrid(wave_obs, flux_obs,  wv_mod, flux_mod)
#plt.plot(rv_grid, ccf_grid)
#rv_best = rv_grid
##opt = minimize(wxcorr_spec_cost, x0=rv_best,                                                                                                                      
##               args=(wave_obs, flux_obs, wv_mod, flux_mod), method="BFGS")

# %% [markdown]
# ### split joint the spectra

# %%
def combine_spectrum_max(waves, fluxs, flux_errs, speclist=None, show=True):
    '''combine spectra of E9+G10 with the maxium ADU
    parameters
    -----------
    waves [2D array] e.g. waves.shape = (11, 2048)
    fluxs [2D array] same as the waves.shape
    flux_errs [2D array] same as the waves.shape
    speclist [1D array of list] the indices of spectra; e.g. [0, 1, 2, 3]
    
    return
    -----------
    wave_dens [1D array] the wavelength of the combine spectrum
    flux_norm [1D array] the normalized flux of combined spectrum
    flux_err [1D array] the flux error of combined spectrum
    '''
    if speclist is None: speclist = np.arange(waves.shape[0])
    
    # set wavelength from minimum to maximum with the minimum delta wave
    delta_wv = 0.1#np.min(np.diff(waves, axis=1))
    #print(delta_wv)
    wv_min, wv_max= np.min(waves), np.max(waves)
    wave_dens = np.arange(wv_min, wv_max, delta_wv)
    
    
    N_wv = len(wave_dens)
    fluxs_dens = np.zeros((fluxs.shape[0], N_wv))
    fluxnorms_dens = np.zeros((fluxs.shape[0], N_wv))
    fluxerrs_dens = np.zeros((fluxs.shape[0], N_wv))
    waves_dens = np.zeros((fluxs.shape[0], N_wv))
    
    
    for fluxi in speclist:
        spec = lk.LightCurve(time=waves[fluxi],  flux=fluxs[fluxi], flux_err=flux_errs[fluxi])
        spec0 = rmcosimic(spec, sigma =5, itera=2, percentile=94,window_length=7, polyorder=2, 
                          show=False)
        ### norlize spectrum
        flux_norm, flux_smoothed2 =lanorm.normalize_spectrum_spline(spec0.time, spec0.flux, p=1E-6, q=0.5, lu=(-1, 3), binwidth=30,
                                      niter=5)
        fluxs_dens[fluxi] = np.interp(wave_dens, spec0.time[50:-50], spec0.flux[50:-50], right=0., left=0.)
        fluxnorms_dens[fluxi] = np.interp(wave_dens, spec0.time[50:-50], flux_norm[50:-50], right=0., left=0.)
        err_frac = np.append(1, np.diff(spec0.time)/delta_wv)
        err2_tmp = spec0.flux_err**2*err_frac
        fluxerrs_dens[fluxi] = np.sqrt(np.interp(wave_dens, spec0.time, err2_tmp/flux_smoothed2**2, right=0., left=0.))
        waves_dens[fluxi] = wave_dens
        if False:
           #ax = spec.scatter(color='b')
           #spec0.plot(ax=ax)
           #ax.plot(spec0.time, flux_smoothed2)
           fig = plt.figure(figsize=(14,5))
           plt.plot(waves[fluxi], flux_norm)
           pltmod =[plt.plot(rvm.wave_mod, _+0.01*__) for __, _ in enumerate(rvm.flux_mod[0:1])]
           plt.xlabel('wavelength')
           plt.plot(wave_dens, fluxnorms_dens[fluxi])
           plt.xlim(waves[fluxi][0], waves[fluxi][-1])

    flx = np.max(fluxs_dens, axis=0)
    ind = fluxs_dens == np.array(list(flx)*fluxs_dens.shape[0]).reshape(fluxs_dens.shape)
    flux_norm = fluxnorms_dens[ind]
    flux_err = fluxerrs_dens[ind]
    wave_dens = waves_dens[ind]
    ind_sort = np.argsort(wave_dens)
    wave_dens = wave_dens[ind_sort]
    flux_norm = flux_norm[ind_sort]
    flux_err = flux_err[ind_sort]
    if show:
       spec = lk.LightCurve(time=wave_dens,  flux=flux_norm, flux_err=None)
       spec.plot()
       plt.xlabel('wavelength')
       plt.ylim(0, 1.3)
    return wave_dens, flux_norm, flux_err

speclist = f1216+f1217+f1218+f1219

flist = speclist[9]
star = combine_wave_flux(flist[0], flist[1])

waves = star['wavelength']['wave_solu']
fluxs = star['flux']['spec_extr']
flux_errs = star['flux']['err_extr']
wave, flux, flux_err = combine_spectrum_max(waves, fluxs, flux_errs, speclist=None, show=True)
plt.xlim(6340, 6450)
plt.axvline(x=4686)

# %%
def combine_spectrum_sum(waves, fluxs, flux_errs, wave_dens=None, speclist=None, show=False):
    '''combine spectra of E9+G10 by summing the overlap zone
    page 28 of specnan2014
    parameters
    -----------
    waves [2D array] e.g. waves.shape = (11, 2048)
    fluxs [2D array] same as the waves.shape
    flux_errs [2D array] same as the waves.shape
    speclist [1D array of list] the indices of spectra; e.g. [0, 1, 2, 3]
    weight [bool] sum with weight
    return
    -----------
    wave_dens [1D array] the wavelength of the combine spectrum
    flux_norm [1D array] the normalized flux of combined spectrum
    flux_err [1D array] the flux error of combined spectrum
    '''
    if speclist is None: speclist = np.arange(waves.shape[0])
    if wave_dens is None:
       delta_wv = 0.1#np.min(np.diff(waves, axis=1))
       wv_min, wv_max= np.min(waves), np.max(waves)
       wave_dens = np.arange(wv_min, wv_max, delta_wv)
    
    speclist = np.arange(waves.shape[0])
    N_wv = len(wave_dens)
    fluxs_dens = np.zeros((fluxs.shape[0], N_wv))
    fluxnorms_dens = np.zeros((fluxs.shape[0], N_wv))
    fluxerrs_dens = np.zeros((fluxs.shape[0], N_wv))
    smoothed_dens = np.zeros((fluxs.shape[0], N_wv))
    waves_dens = np.zeros((fluxs.shape[0], N_wv))
    
    for fluxi in speclist:
        spec = lk.LightCurve(time=waves[fluxi],  flux=fluxs[fluxi], flux_err=flux_errs[fluxi])
        spec0 = rmcosimic(spec, sigma =5, itera=2, percentile=94,window_length=7, polyorder=2, 
                          show=False)
        ### norlize spectrum
        flux_norm, flux_smoothed2 =lanorm.normalize_spectrum_spline(spec0.time, spec0.flux, p=1E-6, q=0.5, lu=(-1, 3), binwidth=30,
                                      niter=5)
        fluxs_dens[fluxi] = np.interp(wave_dens, spec0.time[50:-50], spec0.flux[50:-50], right=0., left=0.)
        smoothed_dens[fluxi] = np.interp(wave_dens, spec0.time[50:-50],flux_smoothed2[50:-50], right=0., left=0.)
        #fluxnorms_dens[fluxi] = np.interp(wave_dens, spec0.time[50:-50], flux_norm[50:-50], right=0., left=0.)
        err_frac = np.append(1, np.diff(spec0.time)/delta_wv)
        err2_tmp = spec0.flux_err**2*err_frac
        #print(np.median(err_frac))
        #fluxerrs_dens[fluxi] = np.sqrt(np.interp(wave_dens, spec0.time, err2_tmp/flux_smoothed2, right=0., left=0.))
        waves_dens[fluxi] = wave_dens
   
    fracs = 1./np.sum(fluxs_dens > 0, axis=0)
    fracs[np.isinf(fracs)] = 0.
    #fluxnorm_sum = np.sum(fluxnorms_dens*fracs, axis=0)
    _fluxs_sum = np.sum(fluxs_dens*fracs, axis=0)
    _smooth_sum = np.sum(smoothed_dens*fracs, axis=0)
    fluxnorm_sum = _fluxs_sum/_smooth_sum
    fluxnorm_err = np.sqrt(_fluxs_sum)/_smooth_sum
    
    if show:
       spec = lk.LightCurve(time=wave_dens,  flux=fluxnorm_sum, flux_err=None)
       spec.plot()
       plt.xlabel('wavelength')
       plt.ylim(0, 1.3)
    return wave_dens, fluxnorm_sum, fluxnorm_err


speclist = f1216+f1217+f1218+f1219

flist = speclist[6]
star = combine_wave_flux(flist[0], flist[1])

waves = star['wavelength']['wave_solu']
fluxs = star['flux']['spec_extr']
flux_errs = star['flux']['err_extr']


#### combine spectra by summing the overlap zones without weight
wave_dens, fluxnorm_sum, fluxnorm_err = combine_spectrum_sum(waves, fluxs, flux_errs, speclist=None)
fig = plt.figure(figsize=(13,4))
plt.plot(wave_dens, fluxnorm_sum)
pltmod =[plt.plot(rvm.wave_mod, _+0.01*__) for __, _ in enumerate(rvm.flux_mod[0:1])]
d = 5000
#plt.xlim(d, d+100)
#plt.xlim(5500, 6000)
plt.ylim(0.5, 1.1)
plt.title('sum without weight')

#### combine spectra by selecting the max flux at overlop zones
wave, flux, flux_err = combine_spectrum_max(waves, fluxs, flux_errs, speclist=None, show=False)
fig = plt.figure(figsize=(13,4))
plt.plot(wave, flux)
pltmod =[plt.plot(rvm.wave_mod, _+0.01*__) for __, _ in enumerate(rvm.flux_mod[0:1])]
#plt.xlim(d, d+100)
#plt.xlim(5500, 6000)
plt.ylim(0.5, 1.1)
plt.title('joint by maximum flux')
# Out:
# Text(0.5, 1.0, 'joint by maximum flux')

# %%
plt.plot(wave_dens, fluxnorm_sum/fluxnorm_err)

# %%
fluxs_dens = np.array([[1,2,3, 4],[3, 5, 7, 2]])
flx = np.max(fluxs_dens, axis=0)
bb = np.array(list(flx)*fluxs_dens.shape[0]).reshape(fluxs_dens.shape)
fluxs_dens == flx
# Out:
# array([[False, False, False,  True],
#        [ True,  True,  True, False]])

# %%
def norm_spectra(waves, fluxs, flux_errs, speclist=None, show=True):
    '''normlize subspectrum
    parameters
    -----------
    waves [2D array] e.g. waves.shape = (11, 2048)
    fluxs [2D array] same as the waves.shape
    flux_errs [2D array] same as the waves.shape
    speclist [1D array of list] the indices of spectra; e.g. [0, 1, 2, 3]
    
    returns
    -----------
    flux_norms [1D array] the normalized flux of combined spectrum
    flux_norm_errs [1D array] the flux error of combined spectrum
    '''
    if speclist is None: speclist = np.arange(waves.shape[0])
    
    flux_norms = np.zeros(fluxs.shape)
    flux_norm_errs = np.zeros(flux_errs.shape)
    
    for fluxi in speclist:
        spec = lk.LightCurve(time=waves[fluxi],  flux=fluxs[fluxi], flux_err=flux_errs[fluxi])
        spec0 = rmcosimic(spec, sigma =5, itera=2, percentile=94,window_length=7, polyorder=2, 
                          show=False)
        ### norlize spectrum
        flux_norm, flux_smoothed2 =lanorm.normalize_spectrum_spline(spec0.time, spec0.flux, p=1E-6, q=0.6, lu=(-1, 3), binwidth=30,
                                      niter=5)
        flux_norm_errs[fluxi] = flux_errs[fluxi]/flux_smoothed2
        flux_norms[fluxi] = flux_norm
        if False:
           ax = spec.scatter(color='b')
           spec0.plot(ax=ax)
           ax.plot(spec0.time, flux_smoothed2)
    
    return flux_norms, flux_norm_errs

# %% [markdown]
# ### calculate hjd, bjd, and [Radial Velocity Corrections](https://docs.astropy.org/en/stable/coordinates/velocities.html)

# %%
from astropy.time import Time
from PyAstronomy import pyasl
from astropy import coordinates as coord
def eval_ltt(ra=62.794724868, dec=50.7082235439, jd=2456326.4583333, site=None, kind='barycentric', barycorr=True):                                                                                                            
    """ evaluate the jd 
    parameters
    ----------
    ra, dec: the coordinate of object
    jd: the julian date of observation
    site: the site of observatory
    return
    ------
    jd_llt: the bjd of hjd
    ltt: light_travel_time
    if barycorr=True return the barycentric correction
    """
    # conf: https://docs.astropy.org/en/stable/time/
    # defaut site is Xinglong
    # coord.EarthLocation.from_geodetic(lat=26.6951*u.deg, lon=100.03*u.deg, height=3200*u.m) lijiang
    if site is None:
        site = coord.EarthLocation.of_site('Beijing Xinglong Observatory')
    # sky position
    ip_peg = coord.SkyCoord(ra, dec, unit=(u.deg, u.deg), frame='icrs')
    # time
    times = Time(jd, format='jd', scale='utc', location=site)
    # evaluate ltt
    ltt = times.light_travel_time(ip_peg,kind)
    jd_llt = times.utc + ltt
    if barycorr is True:
       _barycorr = ip_peg.radial_velocity_correction(obstime=Time(times.iso), location=site)
       return jd_llt.jd, ltt, _barycorr
    else:
       return jd_llt.jd, ltt


def rvcorr_spec(wave, flux, fluxerr, rv, wave_new=None, left=np.nan, right=np.nan):
    ''' correct spectrum with radial velocity
    parameters:
    ------------
    wave [1d array]
    flux [1d array]
    fluxerr [1d array]
    barycorr [float] barycentric radial velocity in units of km/s
    
    returns:
    ----------
    flux_bc [1d array]
    fluxerr_bc [1d array]
    '''
    wvl = wave
    flux = flux
    obsjd = star['flux']['JD']
    jd_llt, ltt, _barycorr = eval_ltt(ra=62.794724868, dec=50.7082235439, jd=2456326.4583333, site=None, kind='barycentric', barycorr=True)
    ## Page 71 of An Introduction to Close Binary Stars
    _barycorr = _barycorr.to('km/s').value
    c = 299792.458
    beta = rv/c
    lgwvl = np.log(wvl)
    gamma =(1+beta)/(1-beta)
    _lgwvl = lgwvl + 0.5*np.log(gamma)
    
    if wave_new is None:
       lgwvl = np.log(wvl)
    else: lgwvl = np.log(wave_new)
    flux_bc = np.interp(lgwvl, _lgwvl, flux, left=left, right=right)
    err2 = np.interp(lgwvl, _lgwvl, fluxerr**2, left=left, right=right)
    fluxerr_bc = np.sqrt(err2)
    return flux_bc, fluxerr_bc

# %% [markdown]
# # put the spectra to a  2D array

# %%
speclist = f1216+f1217+f1218+f1219
wvl = np.arange(3600, 8850, 0.1)
n_speclist, n_wvl = len(speclist), len(wvl) 
fluxall = np.zeros((n_speclist, n_wvl))
fluxerrall = np.zeros((n_speclist, n_wvl))
obsjds = np.zeros(n_speclist)
for _i, flist in enumerate(speclist):
    star = combine_wave_flux(flist[0], flist[1])
    jd = star['flux']['JD']
    obsjds[_i] = jd
    jd_llt, ltt, barycorr = eval_ltt(ra=62.794724868, dec=50.7082235439, jd=2456326.4583333, site=None, kind='barycentric', barycorr=True)
    waves = star['wavelength']['wave_solu']
    fluxs = star['flux']['spec_sum']
    flux_errs = star['flux']['err_sum']
    wave, flux, flux_err = combine_spectrum_sum(waves, fluxs, flux_errs, speclist=None, show=False)
    rv = barycorr.to('km/s').value
    flux_bc, fluxerr_bc = rvcorr_spec(wave, flux, flux_err, rv, wave_new=wvl)
    fluxall[_i] = flux_bc
    fluxerrall[_i] = fluxerr_bc

# %%
fig = plt.figure(figsize=(17, 18))
axs = fig.subplots(3,1)
for _i in np.arange(fluxall.shape[0]):
    
    axs[0].plot(wvl, fluxall[_i]+_i*0.05)
    axs[1].plot(wvl, fluxall[_i]+_i*0.05)
    axs[2].plot(wvl, fluxall[_i]+_i*0.05)
    _i+=1
    
axs[0].set_ylim(0.5, 1.9)
axs[0].axvline(x=4686)
axs[0].set_xlim(4600, 4800)

axs[1].set_ylim(0.5, 1.9)
axs[1].set_xlim(6500, 6670)
axs[1].axvline(x=6614)
axs[1].axvline(x=6563)

axs[2].set_ylim(0.5, 1.9)
axs[2].set_xlim(8600, 8900)
axs[2].axvline(x=8665)
axs[2].axvline(x=8751)
axs[2].axvline(x=8863)
axs[2].axvline(x=8234)

# %% [markdown]
# ### Now, calculate radial velocity

# %% [markdown]
# ### ceck sigle spectrum and its CCF

# %%
from laspec import ccf
speclist = f1216+f1217+f1218+f1219

flist = speclist[2]
star = combine_wave_flux(flist[0], flist[1])

waves = star['wavelength']['wave_solu']
fluxs = star['flux']['spec_sum']
flux_errs = star['flux']['err_sum']
wave, flux, flux_err = combine_spectrum_max(waves, fluxs, flux_errs, speclist=None, show=False)
ind = ~( (flux > 1.1) |
        (wave < 3800) |
        ((wave >5820) & (wave < 6300))|
        ((wave > 6800) & (wave < 7000)) |
        ((wave > 6500) & (wave < 6640))|
        (wave > 7400) 
       ) 

#ind = ~( (flux > 1.05) |
#        (wave < 3900) |
#        (wave  > 4400) |
#        ((wave > 4395)&(wave < 4480))
#       ) 

#ind =  ~((flux > 1.1) |
#        ((wave > 4000)) 
#        ) 

if True:
   spec = lk.LightCurve(time=wave[ind], flux=flux[ind], flux_err=flux_err[ind]) 
   ax = spec.plot()
wave_obs, flux_obs = wave[ind], flux[ind]
flux_norms, flux_norm_errs = norm_spectra(waves, fluxs, flux_errs)
#rvr = rvm.measure(wave_obs, flux_obs)
rv_grid=np.linspace(-600, 600, 100)
ccf_grid = np.zeros((rvm.flux_mod.shape[0], rv_grid.shape[0]))
w_mod = rvm.weight_mod
for imod in range(rvm.nmod):
    ccf_grid[imod] = ccf.wxcorr_rvgrid(wave_obs, flux_obs, rvm.wave_mod, rvm.flux_mod[imod],
                                   w_mod=w_mod[imod], w_obs=None, rv_grid=rv_grid)[1]


fig = plt.figure(figsize=(14,9))
plt.plot(wave[ind], flux[ind])
#pltnorm = [plt.plot(waves[_], flux_norms[_]) for _ in np.arange(flux_norms.shape[0])]
pltmod =[plt.plot(rvm.wave_mod, _+0.01*__) for __, _ in enumerate(rvm.flux_mod[0:1])]
plt.xlabel('wavelength')
d = 3700
plt.xlim(d, d+350)
plt.ylim(0.5, 1.1)
plt.axvline(x=3926.5, ls='--')

fig = plt.figure()
tt= plt.plot(rv_grid, ccf_grid.T)

# %% [markdown]
# ### plot the sub spectra and template spectrum

# %%
for i in np.arange(flux_norms.shape[0])[0:2]:
    fig = plt.figure(figsize=(14,5))
    plt.plot(waves[i], flux_norms[i])
    pltmod =[plt.plot(rvm.wave_mod, _+0.01*__) for __, _ in enumerate(rvm.flux_mod[0:1])]
    plt.xlabel('wavelength')
    plt.xlim(waves[i][0], waves[i][-1])
    #d = 3700
    #plt.xlim(d, d+350)

# %%
fig = plt.figure(figsize=(17, 5))
axs = fig.subplots(1,1)
for _i in np.arange(fluxall.shape[0]):
    wave = wvl
    flux = fluxall[_i]
    flux_err = fluxerrall[_i]
    ind = ~( (flux > 1.1) |
            (wave < 3800) |
            ((wave >5820) & (wave < 6000))|
            ((wave > 6800) & (wave < 7000)) |
            ((wave > 6500) & (wave < 6640))|
            (wave > 7400) 
           ) 
    ind = ~( (flux > 1.1) |
        (wave < 3800) |
        ((wave >5820) & (wave < 6300))|
        ((wave > 6800) & (wave < 7000)) |
        ((wave > 6500) & (wave < 6640))|
        (wave > 7400) 
       ) 
    if _i == 0 :
       _wave = wave.copy(); _wave[~ind]=np.nan
       _flux = flux.copy(); _flux[~ind] = np.nan
       _flux_err = flux_err; _flux_err[~ind] = np.nan
       spec = lk.LightCurve(time=_wave, flux=_flux, flux_err=_flux_err) 
       spec.plot(ax=axs)
    wave_obs, flux_obs = wave[ind], flux[ind]
    flux_err_obs = flux_err[ind]
    #rvr = rvm.measure(wave_obs, flux_obs)
    rvr = rvm.measure(wave_obs, flux_obs, flux_err=flux_err_obs, nmc=100, rv_grid=np.arange(-1000, 1000, 5),
                    )
    rvs[star['flux']['JD']]= rvr
    rvr

# %% [markdown]
# # coadd specra
#
# Page 127: 4.2.6. TheMLE Applied to a Heteroscedastic Gaussian Likelihood
#
# - $\mu^0 = \frac{ \sum_l^N \omega_{l}x_{l}}{\sum_l^N \omega_{l}}$
#
# - $\sigma_{\mu} = \left( \sum_l^N\frac{1}{\sigma_l^2} \right)^{-1/2} = \left( \sum_l^N\omega_l \right)^{-1/2}$

# %%
_fluxall = np.zeros_like(fluxall)
_fluxerrall = np.zeros_like(_fluxall)
for _i in np.arange(fluxall.shape[0]):
    wave = wvl
    flux = fluxall[_i]
    flux_err = fluxerrall[_i]
    rv = rvs[obsjds[_i]]['rv_opt']
    flux_rv, fluxerr_rv = rvcorr_spec(wave, flux, flux_err, rv, left=0., right=0.)
    _fluxall[_i] = flux_rv
    _fluxerrall[_i] = fluxerr_rv
    

fig = plt.figure(figsize=(15, 5))
axs = fig.subplots(1,1)
plt.plot(_fluxerrall[0])

# %%
_ind = _fluxall > 0.
_fluxallma = np.ma.array(fluxall, mask=~_ind)

_std = np.ma.std(_fluxallma, axis=0, ddof = 1)
_mean = np.ma.mean(_fluxallma, axis=0)
_indma = np.ma.abs(_fluxallma - _mean) < 4*_std

ivar = 1./_fluxerrall**2
ivar = np.ma.array(ivar, mask=~_indma.data)
sumivar = np.ma.sum(ivar, axis=0)
flux_coadd =  np.ma.sum(_fluxall * ivar/sumivar, axis=0)
err_coadd = 1/np.sqrt(sumivar)

fig = plt.figure(figsize=(17, 5))
axs = fig.subplots(1,1)
plt.plot(wvl, flux_coadd)
#plt.xlim(6500, 6600)

# %%
_wvl = np.arange(3600, 4000, 1)
_flux_tmp = np.interp(_wvl, wvl, flux_coadd)

fig = plt.figure(figsize=(17, 5))
axs = fig.subplots(1,1)
plt.plot(_wvl, _flux_tmp)

# %%
# Out:
# masked_array(data=[1166.4643869519198, 1170.1198372378337,
#                    1172.3704071933105, ..., 16241.007685499782,
#                    16234.278717470652, 11968.611630732692],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value=1e+20)

# %%
ivar = 1./_fluxerrall**2
sumivar = np.sum(ivar, axis=0)
#4.2.6. TheMLE Applied to a Heteroscedastic Gaussian Likelihood (Statistics, Data Mining, and Machine Learning in Astronomy)
ff = np.sum(_fluxall * ivar/sumivar, axis=0)

# %%
fig = plt.figure(figsize=[15,5])
ax = fig.subplots(1,1)
ax.plot(wave, ff)
wv0 = 6900
dw = 300
#ax.set_xlim(wv0, wv0+dw)

# %%
imod = []
for iii in rvs:
    imod.append(rvs[iii]['imod'])
imod = list(set(imod))
rvm.pmod[imod]
# Out:
# array([[3.25e+04, 4.00e+00, 1.00e+01, 2.00e-01],
#        [3.25e+04, 4.00e+00, 1.00e+01, 5.00e-01],
#        [3.25e+04, 4.00e+00, 1.00e+01, 1.00e+00]])

# %%
_times = Time(times, format='jd', scale='utc', location=site).iso
site = coord.EarthLocation.from_geodetic(lat=26.6951*u.deg, lon=100.03*u.deg, height=3200*u.m)
sp = coord.SkyCoord(ra=62.794724868, dec=50.7082235439, unit=(u.deg, u.deg), frame='icrs')
barycorr = sp.radial_velocity_correction(obstime=Time(['2016-6-4', '2016-6-5']), location=site)
barycorr = sp.radial_velocity_correction(obstime=Time(_times), location=site)

# %%
Time(_times)
# Out:
# <Time object: scale='utc' format='iso' value=['2020-12-16 13:21:40.000' '2020-12-16 16:39:43.000'
#  '2020-12-16 20:47:07.000' '2020-12-17 13:05:42.000'
#  '2020-12-17 16:17:45.000' '2020-12-17 20:12:17.000'
#  '2020-12-18 12:52:41.000' '2020-12-18 15:56:21.000'
#  '2020-12-18 20:34:54.000' '2020-12-19 13:05:16.000'
#  '2020-12-19 16:01:00.000' '2020-12-19 20:33:55.000']>

# %%
Time(['2016-6-4', '2016-6-5'])
# Out:
# <Time object: scale='utc' format='iso' value=['2016-06-04 00:00:00.000' '2016-06-05 00:00:00.000']>

# %%
np.sqrt(np.sum(np.square(np.diff(rvs[2459200.056712963]['rv_pct']))/2))
# Out:
# 35.61500951817925

# %%
plt.style.use('lijiaostyle')

times = []
rv_best = []
rv_err =[]
speci = 8
for time in rvs:
    times.append(time)
    rv_best.append(rvs[time]['rv_opt'])
    _rv_err = np.sqrt(np.sum(np.square(np.diff(rvs[time]['rv_pct']))/2))
    rv_err.append(_rv_err)
    
times = np.array(times)
bjd, ltt, corr= eval_ltt(ra=62.794724868, dec=50.7082235439, jd=times, kind='heliocentric', barycorr=True)
rv_best = np.array(rv_best)+corr.to('km/s').value
fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot(111)
plt.scatter(bjd-2459200, rv_best)
ax.set_xlabel(r'$JD -2459200  (day)$')
ax.set_ylabel(r'$rv (km/s)$')
plt.ylim(-200, 200)
# Out:
# (-200.0, 200.0)

# %% [markdown]
# # save 216 rv to a joblibdump

# %%
rv_216 = lk.LightCurve(time=bjd,  flux=rv_best, flux_err=rv_err)
#rv_216.scatter()
joblib.dump(rv_216, '../dump/rv_216.dump')
# Out:
# ['../dump/rv_216.dump']

# %%
# Out:
# lijiao@10.0.9.41's password:

# %%
corr.to('km/s').value
# Out:
# array([-6.51858832, -6.76815868, -6.95721609, -6.95189214, -7.19462732,
#        -7.39398232, -7.3864451 , -7.61866112, -7.84795922, -7.84927585,
#        -8.07154081, -8.29068896])

# %%
ra=62.794724868
dec=50.7082235439
corr, hjd = pyasl.helcorr(sit.lon.degree, sit.lat.degree, sit.height.value, \
                          ra, dec, times[0], debug=False)

# %%
obstimei = 1
verbose =True
dwave =200
rvs = {}
speclist = [3, 4, 5, 6, 7, 8]
for i in speclist:
    rvs[i] = {}

for flist in f1216+f1217+f1218+f1219:
    star = combine_wave_flux(flist[0], flist[1])
    wave = star['wavelength']['wave_solu']
    flux = star['flux']['spec_sum']
    flux_err = star['flux']['err_sum']
    # set wavelength from minimum to maximum with the minimum delta wave
    delta_wv = np.min(np.diff(wave, axis=1))
    wv_min, wv_max= np.min(wave), np.max(wave)
    if verbose: print(wv_min, wv_max)
    wavelength = np.arange(wv_min, wv_max, delta_wv)
    #flux_join = np.zeros(len(wavelength))
    #flux_err_join2 = np.zeros(len(wavelength)) ## asumming the err**2 are linear
    #ind_overlap = np.zeros([wave.shape[0], len(wavelength)])
    for i in speclist: #np.arange(wave.shape[0]):
        spec = lk.LightCurve(time=wave[i],  flux=flux[i], flux_err=flux_err[i])
        spec0 = rmcosimic(spec, sigma =6, itera=2, percentile=100,window_length=7, 
                  polyorder=2, 
                  show=False)
        #flux_norm, flux_smoothed2 =lanorm.normalize_spectrum(spec0.time, spec0.flux, 
        #                   (np.min(wv), np.max(wv)), dwave,
        #                   p=(1E-6, 1E-6), q=0.5, ivar=None, eps=1e-10,
        #                   rsv_frac=1.)
        #spec_norm = lk.LightCurve(time=wv,  flux=flux_norm, flux_err=spec0.flux_err/flux_smoothed2)
        #flux_t = np.interp(spec0.time, wv_ispec, flx_ispec)
        flux_norm, flux_smoothed2 =lanorm.normalize_spectrum_spline(spec0.time, spec0.flux, p=1E-6, q=0.6, lu=(-1, 3), binwidth=30,
                                  niter=5)
        if i == 4:
           ind_good = (spec0.time > 4600) & (spec0.time < 5200) &(spec0.flux > 250)
        elif i ==8:
           ind_good = (spec0.time > 6800) & (spec0.flux > 250)
        else: ind_good = (spec0.flux > 250)
        wave_obs, flux_obs = spec0.time[ind_good], flux_norm[ind_good]
        flux_err_obs = 
        rvr = rvm.measure(wave_obs, flux_obs)
        #rvr = rvm.measure(msr.wave, msr.flux_norm, flux_err=msr.flux_norm_err, nmc=100, rv_grid=np.arange(-1000, 1000, 10),
        #                 twin=True, eta_init=0.3, eta_lim=(0, 2))
        rvs[i][star['flux']['JD']] = rvr
        #spec0.plot()
        #plt.plot(spec0.time, flux_smoothed2)
        plt.plot(spec0.time, flux_norm)
        #plt.plot(wv_new, flux_new)
        #plt.plot(wavelength, flux_err_join)
        #flux_interp = np.interp(wavelength, spec0.time, flux_norm, left=0, right=0)
        #ind_overlap[i] = flux_interp > 0
        #flux_join += flux_interp 
        #flux_err_join2 += np.interp(wavelength, spec0.time, spec0.flux_err/flux_smoothed2**2, left=0, right=0)

    
#plt.plot(wavelength, flux_join)
# Out:
# 3573.7895692853817 8940.30209024206
# 3573.717694387653 8939.31740117835
# 3574.0429980905556 8938.630107384359
# 3573.933674232216 8940.21197271834
# 3573.942971599485 8939.61731599936
# 3574.0246339727983 8938.832833313138
# 3573.902795934411 8940.415185716984
# 3573.6166057113974 8939.59466547712
# 3573.472898272646 8938.642813018929
# 3574.006061966732 8940.403831565
# 3573.5059979836224 8939.738635941665
# 3574.0144527631537 8938.586363498523

# %%
dirname = '/media/share/lijiao/TLUSTY_grid/TLUSTY_OSTAR2002_R2500'
fname = os.path.join(dirname, 'C27500g300v10.fits.gz')

# %%
flux_norm[ind_good]
# Out:
# array([], dtype=float64)

# %%
bjd
# Out:
# array([2459200.06153043, 2459200.19906211, 2459200.37086373,
#        2459201.05042   , 2459201.18378492, 2459201.34665132,
#        2459202.04135668, 2459202.16889978, 2459202.36233228,
#        2459203.0500692 , 2459203.172103  , 2459203.36162328])

# %%
lamost_hjd = np.array([2458452.12364954, 2458452.13988804, 2458452.16656641,
       2458452.18334889, 2458452.20084897, 2458452.21706432,
       2458452.23349957, 2458482.10998174, 2458482.15857932,
       2458482.14237627, 2458482.12618479, 2458482.09377868,
       2458508.98220653, 2458508.95675695, 2458508.96948753])

lamost_rv = np.array([-47.68426521, -49.97441618, -49.29633668, -59.25010231,
       -66.68764891, -57.46987868, -68.64643026,  39.97841072,
        29.1913021 ,  32.75776442,  33.69146886,  47.26582088,
        76.97345401,  69.14904601,  71.41999393])

# %%
_bjd, _ltt, lamostcorr = eval_ltt(ra=62.794724868, dec=50.7082235439, site=None, jd=lamost_hjd, kind='heliocentric', barycorr=True)

# %%
rv_best+corr.to('km/s').value
# Out:
# array([  61.96282336,   68.86290875,   72.2345374 ,  -22.68736098,
#         -30.49152618,  -49.78796463, -123.95606307, -117.43769931,
#         -95.69591844,  -16.5847477 ,    6.38326312,   37.22619675])

# %%
tt = np.append(lamost_hjd, bjd)
rv_corr = np.append(lamost_rv, rv_best-corr.to('km/s').value)
rv = np.append(lamost_rv, rv_best)
lc = lk.LightCurve(time=tt-2458452,  flux=rv, flux_err=None)
rv = np.append(lamost_rv, rv_best)
lc_corr = lk.LightCurve(time=tt-2458452,  flux=rv, flux_err=None)
lc_lamost = lk.LightCurve(time=lamost_hjd-2458452,  flux=lamost_rv, flux_err=None)
lc_lamost_corr = lk.LightCurve(time=lamost_hjd-2458452,  flux=lamost_rv+lamostcorr.to('km/s').value, flux_err=None)
#fig = plt.figure(figsize=(7,4))
#ax = fig.add_subplot(111)
#plt.scatter(tt-2459200, rv)
#ax.set_xlabel(r'$JD -2459200  (day)$')
#ax.set_ylabel(r'$rv (km/s)$')
lc.scatter(s = 20)
plt.scatter(lamost_hjd-2458452, lamost_rv, c='b', label='lamost')
plt.ylabel('rv km/s')
plt.xlabel('HDJ - 2458452 (day)')


### fold the radial velocity
period=3.3893#6.75#1.669*4#10**0.676
print(period)
#lc_fold = lc.fold(period=period, t0 = tt[np.argmin(lc.flux)])
lc_corr_fold = lc_corr.fold(period=period, t0 = tt[np.argmin(lc.flux)])
#lc_fold = lc.fold(period=period, t0=2458815)
#lc_lamost_fold = lc_lamost.fold(period=period, t0 = tt[np.argmin(lc.flux)])
lc_lamost_corr_fold = lc_lamost_corr.fold(period=period, t0 = tt[np.argmin(lc.flux)])
ax = lc_fold.scatter( s=20)
lc_lamost_fold.scatter(ax=ax, color='b', s=20, label='LAMOST')
lc_corr_fold.scatter(ax=ax)
lc_lamost_corr_fold.scatter(ax=ax, c='r')
plt.ylabel('rv km/s')
plt.title(f'P={period} day')
plt.legend(numpoints=1, fontsize=15)
# Out:
# 3.3893

# %%
fig = plt.figure(figsize=(13,5))
plt.scatter(lc_fold.phase+ 0.4975819931262322, lc_fold.flux, s=6, c='k')
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
ind_min = np.argmin(rv)
t_min = tt[ind_min]
print(t_min)
t_max = t_min + period/2
time = Time(t_max, format='jd', scale='utc', location=site)
# Out:
# 2459202.0413566763

# %%
llp = lc.to_periodogram(period=np.arange(1, 20, 0.001))
power = llp.power
iind
# Out:
# The requested periodogram is not evenly sampled in frequency.
# Method has been changed from 'fast' to 'slow' to allow for this.
# <Quantity [38.19955514, 41.86182001, 46.41707162, ..., 31.62678273,
#            31.71051189, 31.79490739]>

# %%
from astropy.table import Table
tab = Table(data=[tt, rv], names=('t', 'rv'))
tab.write('zsx.csv')

plt.plot(tt[15:], rv[15:], '.')
# Out:
# WARNING: AstropyDeprecationWarning: zsx.csv already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]

# %%
dire = '/media/backup/216BFOSC/20201217_bfosc/'
fwave = 'fear-20201217-0027.fit.dump'
fflux = 'star-20201217-0026.fit.dump'
# Out:
# (0.0, 9000.0)

# %%
'fear-20201217-{:04d}.fit.dump'.format(11)
# Out:
# 'fear-20201217-0011.fit.dump'

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
for j, fname in enumerate(f1216 + f1217+f1218):
    wave = joblib.load(fname[0])['wave_solu']
    flux = joblib.load(fname[1])
    
    for i in np.arange(wave.shape[0])[8:9]:
        ax.plot(wave[i], j*0.15+flux['spec_sum'][i]/np.median(flux['spec_sum'][i]))

plt.vlines(6560,0,4)
plt.vlines(6565,0,4)
plt.xlim(6545, 6585)
#plt.xlim(6600, 6700)
#plt.xlim(4800, 5000)
plt.ylim(1,3)
# Out:
# (1.0, 3.0)

# %%
dulist = fits.open('../iraf_template/20200314-0103_tbf_ecw_cut.fits')
#dulist[0].header

# %%
### TYC3340-2437-1 04:11:10.00   +50:42:29.0 

###-----------20201216----------------------------
dire1 = '/media/backup/216BFOSC/20201216_bfosc/'
fwave1 = 'fear-20201216-{:04d}.fit.dump'
fflux1 = 'star-20201216-{:04d}.fit.dump'
list16 = [[30, 31], [41, 40], [54, 55]]
f1216 = [[os.path.join(dire1, fwave1.format(_[0])), os.path.join(dire1, fflux1.format(_[1]))] for _ in list16]
###-----------20201217----------------------------
dire2 = '/media/backup/216BFOSC/20201217_bfosc/'
fwave2 = 'fear-20201217-{:04d}.fit.dump'
fflux2 = 'star-20201217-{:04d}.fit.dump'
list17 = [[27, 26], [36, 35], [49, 50]]
f1217 = [[os.path.join(dire2, fwave2.format(_[0])), os.path.join(dire2, fflux2.format(_[1]))] for _ in list17]

###-----------20201218----------------------------
dire3 = '/media/backup/216BFOSC/20201218_bfosc/'
fwave3 = 'fear-20201218-{:04d}.fit.dump'
fflux3 = 'star-20201218-{:04d}.fit.dump'
list18 = [[16, 17], [32, 31], [56, 55]]
f1218 = [[os.path.join(dire3, fwave3.format(_[0])), os.path.join(dire3, fflux3.format(_[1]))] for _ in list18]



fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
for j, fname in enumerate(f1216 + f1217+f1218):
    wave = joblib.load(fname[0])['wave_solu']
    flux = joblib.load(fname[1])
    
    for i in np.arange(wave.shape[0])[8:9]:
        ax.plot((wave[i]-6563)/6563*3.e5, j*0.15+flux['spec_sum'][i]/np.median(flux['spec_sum'][i]))

#plt.vlines(6560,0,4)
#plt.vlines(6565,0,4)
#plt.xlim(6545, 6585)
plt.xlim(-1000, 1000)
#plt.xlim(4800, 5000)
plt.ylim(1,3)
# Out:
# (1.0, 3.0)

# %%
dire = '/media/backup/216BFOSC/20201217_bfosc/'
fwave = 'fear-20201217-0049.fit.dump'
fflux = 'star-20201217-0050.fit.dump'

wave = joblib.load(os.path.join(dire, fwave))['wave_solu']
flux = joblib.load(os.path.join(dire, fflux))
fig = plt.figure(figsize=(13,4))
ax = fig.add_subplot(111)
for i in np.arange(wave.shape[0]):
    ax.plot(wave[i], flux['spec_sum'][i])
plt.ylim(0,9000)
# Out:
# (0.0, 9000.0)

# %%
3/6563*3.e5
# Out:
# 137.1324089593174

# %%
1.422 - (4.32 - 2.54)
# Out:
# -0.3580000000000003

# %%
rvr = rvm.measure_binary(msr.wave, msr.flux_norm, flux_err=msr.flux_norm_err, nmc=100, rv_grid=np.arange(-1000, 1000, 10),
                         twin=True, eta_init=0.3, eta_lim=(0, 2))
# Out:
# {2459200.056712963: {'rv_opt': 77.19327929439154,
#   'rv_err': 96389.42739520958,
#   'rv_best': 78.78787878787875,
#   'ccfmax': 0.28054856524762123,
#   'success': True,
#   'imod': 1,
#   'pmod': array([3.25e+04, 4.00e+00, 1.00e+01, 5.00e-01]),
#   'status': 0},
#  2459200.1942476854: {'rv_opt': 82.3494928262812,
#   'rv_err': 46474.002154380556,
#   'rv_best': 78.78787878787875,
#   'ccfmax': 0.8120807037523996,
#   'success': True,
#   'imod': 0,
#   'pmod': array([3.25e+04, 4.00e+00, 1.00e+01, 2.00e-01]),
#   'status': 0},
#  2459200.366053241: {'rv_opt': 86.51765759170245,
#   'rv_err': 108305.78859985656,
#   'rv_best': 90.90909090909088,
#   'ccfmax': 0.28630920404812193,
#   'success': True,
#   'imod': 5,
#   'pmod': array([3.25e+04, 4.00e+00, 1.00e+01, 1.00e+00]),
#   'status': 0},
#  2459201.045625: {'rv_opt': -8.719070165797017,
#   'rv_err': 48027.61655743252,
#   'rv_best': -6.060606060606119,
#   'ccfmax': 0.7820670618881317,
#   'success': True,
#   'imod': 0,
# ...

# %%
from glob import glob

# %%
import os

# %%
ifile = filelist[0]

# %%
basename = os.path.basename(ifile)

# %%
basename[8:12]
# Out:
# '0225'
